# %% [markdown]
# ## Atividade de Classificação de Imagens com Fashion Mnist
#
# Aluno: João Guilherme Lopes Alves da Costa
#
# Professor: Ranniery da Silva Maia
#
# Disciplina: DIM0446 - APRENDIZADO PROFUNDO

# %% [markdown]
# Inicialmente foi feito o import das bibliotecas necessárias para a análise, como o `numpy` para uso de funções matemáticas, `matplotlib` para plotar gráficos, `tensorflow` para realizar treinamento de aprendizado profundo e `sklearn` para análise do treinamento.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# Nesse momento definimos que nossa base de dados será a `mnist`, utilizada para treinamento de processamento de imagens. Logo em seguida, definimos a base de treinamento e de teste.

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28) (60000,) (10000,)

# %% [markdown]
# Agora só iremos exibir um dos dados de treino em formato de gráfico/imagem.

# %%
plt.imshow(X_train[1], cmap="gray")
plt.title(f"{y_train[1]}")
plt.show()

# %% [markdown]
# Será necessário dividir os dados por 255 para termos valores entre 0 e 1, uma forma de normalizar os dados e facilitar o aprendizado. O número 255 é pelo fato de que as imagens são representadas com valores de pixel entre 0 e 255.

# %% [markdown]
# Por que normalizar os dados dessa forma? Podemos citar alguns motivos:
# - Melhor convergência: funções de ativação respondem melhor quando as entradas estão em uma faixa de valores menores.
# - Consistência: com os dados normalizados temos uma escala semelhante aos dados de entrada, melhorando a capacidade de **generalização** do modelo.
# - Evitar overflow: valores em uma faixa menor evita problemas de overflow e estabilidade numérica.

# %%
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255

# %% [markdown]
# Nesse momento estamos expandindo os arrays para uma dimensão a mais ao final do array. Isso é feito para dados de entrada de redes neurais que esperam a dimensão de canais.

# %%
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)
print(X_train.shape,X_test.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)

# %% [markdown]
# Agora utilizaremos o método `utils.to_categorical` para aplicar o **one-hot enconding** aos dados. Esse one-hot enconding consiste em transformar dados categóricos (classes) em uma matriz de zeros e um número 1, representando a classe que ele pertence.
#
# Essa transformação é útil para ser repassada para dados de entrada de redes neurais.
#
# Ou seja, até o momento fizemos o pré-processamento dos dados.

# %%
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
print(y_train.shape,y_test.shape)
# Out:
# (60000, 10) (10000, 10)

# %% [markdown]
# Neste momento iremos definir o **modelo** de aprendizado de máquina a ser utilizado. No caso iremos utilizar Rede Neural Convolucional (CNN). Cada linha dentro da definição do array de parâmetro é uma camada da rede, no caso temos primeiro a camada de entrada, depois definimos camadas convolucionais, camadas de pooling, temos o Flatten para transformar em um vetor unidimensional e por fim a camada densa que vai fornecer a saída do modelo.

# %%
model = keras.Sequential([
    keras.Input(shape=(28,28,1)),
    layers.Conv2D(32, kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Dropout(0.5),
    layers.Conv2D(64, kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Dropout(0.5),
    layers.Conv2D(128, kernel_size=(3,3), activation="relu"),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Dropout(0.5),
    layers.Flatten(),
    layers.Dense(num_classes, activation="softmax")
])
print(model)
# Out:
# <Sequential name=sequential_8, built=True>

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_16 (Conv2D)                   │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_15 (MaxPooling2D)      │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 3, 3, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_16 (MaxPooling2D)      │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_8 (Flatten)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 93,962 (367.04 KB)
#  Trainable params: 93,962 (367.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# A partir de agora iremos definir alguns parâmetros que gostaríamos para o modelo. Note que ainda não realizamos o processo de treinamento, logo podemos considerar que as seguintes definições são **hiperparâmetros**.
#
# Alguns parâmetros que estamos definindo:
# - `Batch_size` define a quantidade de amostras a ser utilizada para calcular o gradiente antes de atualizar os pesos.
# - `Epochs` é o número de épocas, ou seja, quantas vezes será treinado o modelo por completo, nesse caso 50 vezes.
# - A função de perda (`loss`) será a categorical_crossentropy. Essa função de perda é como o modelo avalia a diferença entre as previsões e o valor verdadeiro.
# - O otimizador (`optim`), ou seja a função que controlará os pesos durante o treinamento será o Adam.
# - Métrica de performance do modelo (`metric`), que será acurácia.

# %%
batch_size = 128
epochs = 40
loss = "categorical_crossentropy"
optim = "adam"
metric = ["accuracy"]

model.compile(loss=loss,
              optimizer=optim,
              metrics=metric)

# %% [markdown]
# Por fim, definimos os dados de treino e de teste, e passamos a divisão de dados, que no caso será de 20% para teste e 80% para treinamento.

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=True, stratify=y_train)

# %%
print(X_train.shape,X_val.shape,y_train.shape,y_val.shape)
# Out:
# (38400, 28, 28, 1) (9600, 28, 28, 1) (38400, 10) (9600, 10)

# %% [markdown]
# Agora iremos de fato realizar o treinamento do modelo, passando alguns parâmetros como o tamanho de épocas, batch_size, entre outros.

# %%
history = model.fit(X_train,
                    y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=(X_val,y_val),
                    shuffle=True)
# Out:
# Epoch 1/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.4419 - loss: 1.4898 - val_accuracy: 0.7484 - val_loss: 0.6918
# Epoch 2/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7210 - loss: 0.7652 - val_accuracy: 0.7769 - val_loss: 0.6027
# Epoch 3/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7470 - loss: 0.6854 - val_accuracy: 0.8062 - val_loss: 0.5529
# Epoch 4/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7619 - loss: 0.6383 - val_accuracy: 0.8215 - val_loss: 0.5224
# Epoch 5/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7741 - loss: 0.6138 - val_accuracy: 0.8266 - val_loss: 0.4919
# Epoch 6/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7876 - loss: 0.5794 - val_accuracy: 0.8306 - val_loss: 0.4872
# Epoch 7/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7967 - loss: 0.5607 - val_accuracy: 0.8397 - val_loss: 0.4626
# Epoch 8/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8048 - loss: 0.5411 - val_accuracy: 0.8496 - val_loss: 0.4384
# Epoch 9/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8098 - loss: 0.5238 - val_accuracy: 0.8507 - val_loss: 0.4239
# Epoch 10/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8145 - loss: 0.5064 - val_accuracy: 0.8556 - val_loss: 0.4106
# Epoch 11/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8190 - loss: 0.4983 - val_accuracy: 0.8575 - val_loss: 0.4087
# Epoch 12/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8243 - loss: 0.4916 - val_accuracy: 0.8577 - val_loss: 0.4069
# Epoch 13/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8275 - loss: 0.4816 - val_accuracy: 0.8620 - val_loss: 0.3937
# Epoch 14/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8275 - loss: 0.4775 - val_accuracy: 0.8677 - val_loss: 0.3851
# Epoch 15/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8312 - loss: 0.4655 - val_accuracy: 0.8677 - val_loss: 0.3786
# Epoch 16/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8322 - loss: 0.4621 - val_accuracy: 0.8696 - val_loss: 0.3790
# Epoch 17/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8368 - loss: 0.4520 - val_accuracy: 0.8661 - val_loss: 0.3721
# Epoch 18/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8357 - loss: 0.4576 - val_accuracy: 0.8716 - val_loss: 0.3717
# Epoch 19/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8396 - loss: 0.4363 - val_accuracy: 0.8701 - val_loss: 0.3698
# Epoch 20/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8393 - loss: 0.4435 - val_accuracy: 0.8723 - val_loss: 0.3645
# Epoch 21/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8398 - loss: 0.4406 - val_accuracy: 0.8753 - val_loss: 0.3605
# Epoch 22/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8389 - loss: 0.4417 - val_accuracy: 0.8756 - val_loss: 0.3527
# Epoch 23/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8436 - loss: 0.4298 - val_accuracy: 0.8732 - val_loss: 0.3602
# Epoch 24/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8403 - loss: 0.4370 - val_accuracy: 0.8740 - val_loss: 0.3689
# Epoch 25/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8439 - loss: 0.4293 - val_accuracy: 0.8800 - val_loss: 0.3438
# Epoch 26/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8468 - loss: 0.4191 - val_accuracy: 0.8751 - val_loss: 0.3592
# Epoch 27/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8505 - loss: 0.4146 - val_accuracy: 0.8741 - val_loss: 0.3530
# Epoch 28/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8449 - loss: 0.4232 - val_accuracy: 0.8773 - val_loss: 0.3477
# Epoch 29/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8506 - loss: 0.4168 - val_accuracy: 0.8816 - val_loss: 0.3445
# Epoch 30/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8497 - loss: 0.4175 - val_accuracy: 0.8821 - val_loss: 0.3407
# Epoch 31/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8485 - loss: 0.4150 - val_accuracy: 0.8807 - val_loss: 0.3375
# Epoch 32/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8526 - loss: 0.4077 - val_accuracy: 0.8829 - val_loss: 0.3364
# Epoch 33/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8569 - loss: 0.4011 - val_accuracy: 0.8803 - val_loss: 0.3398
# Epoch 34/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8558 - loss: 0.4049 - val_accuracy: 0.8855 - val_loss: 0.3332
# Epoch 35/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8503 - loss: 0.4138 - val_accuracy: 0.8830 - val_loss: 0.3366
# Epoch 36/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8555 - loss: 0.3983 - val_accuracy: 0.8826 - val_loss: 0.3343
# Epoch 37/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8545 - loss: 0.4044 - val_accuracy: 0.8847 - val_loss: 0.3315
# Epoch 38/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8574 - loss: 0.3915 - val_accuracy: 0.8790 - val_loss: 0.3372
# Epoch 39/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8513 - loss: 0.4052 - val_accuracy: 0.8859 - val_loss: 0.3268
# Epoch 40/40
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8537 - loss: 0.3931 - val_accuracy: 0.8833 - val_loss: 0.3285

# %% [markdown]
# Plotamos 2 gráficos para conseguir compreender melhor o comportamento do nosso modelo em relação a métrica de erro e de acurácia ao longo do treinamento:

# %%
plt.figure()
plt.plot(history.epoch, history.history["val_loss"], "o-r", label="Validação")
plt.plot(history.epoch, history.history["loss"], "-y", label="Treino")
plt.xlabel("Época")
plt.ylabel("Erro")
plt.legend()

plt.figure()
plt.plot(history.epoch, history.history["val_accuracy"], "o-r", label="Validação")
plt.plot(history.epoch, history.history["accuracy"], "-y", label="Treino")
plt.xlabel("Época")
plt.ylabel("Acurácia")
plt.legend()

# %% [markdown]
# Aqui obtemos as métricas de desempenho do nosso modelo durante o treinamento:

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print(f"Custo na base de teste: {score[0]}")
print(f"Acurácia na base de teste: {score[1]}")
# Out:
# Custo na base de teste: 0.3363456428050995
# Acurácia na base de teste: 0.8752999901771545

# %% [markdown]
# Por fim, realizaremos um teste do modelo para ver se ele prediz corretamente:

# %%
y_test_hat = model.predict(X_test)
y_pred = np.argmax(y_test_hat, axis=1)
y_true = np.argmax(y_test, axis=1)
print(y_pred.shape,y_true.shape)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# (10000,) (10000,)

# %% [markdown]
# Por fim, mais uma forma de avaliar o nosso modelo (e a melhor delas), é através de matriz de confusão. Muito utilizada para avaliar modelos de classificação e conseguimos ver através de um mapa de calor onde está sendo maior a proporção de erros.

# %%
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt=".0f", cmap="Blues")
# Out:
# <Axes: >
